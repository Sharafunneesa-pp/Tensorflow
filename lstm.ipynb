# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Flatten

# %%
sales=[110, 125, 133, 146, 158, 172, 187, 196, 210]
n_feature=3
x,y=[],[]
for i in range(len(sales)-n_feature):
    x.append(sales[i:i+n_feature])
    y.append(sales[i+n_feature])
x=np.array(x)
y=np.array(y)

# %%
x=-x.reshape(x.shape[0],1,x.shape[1])

# %%
y=data['y'].values

# %%
model=Sequential()
model.add(LSTM(50,input_shape=(x.shape[1],x.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')
model.fit(x,y,epochs=500,verbose=1)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - loss: 32414.7500
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32372.5020
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32328.1191
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32293.9590
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32269.6387
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32250.5293
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32234.3965
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32220.6719
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32209.1660
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32199.6016
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 32191.5625
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32184.5859
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32178.2266
# Epoch 14/500
# ...

# %%
# predictions = []
# last_sequence = sales[-n_feature:]  # Last n_feature days from historical data

# # for _ in range(5):
# #     # Reshape last_sequence for prediction
# #     input_data = np.array(last_sequence).reshape((1, n_feature, 1))
    
# #     # Predict next day's sales
# #     next_day_pred = model.predict(input_data, verbose=0)[0][0]
# #     predictions.append(next_day_pred)
    
# #     # Update the last sequence with the new prediction
# #     last_sequence.append(next_day_pred)
# #     last_sequence = last_sequence[1:]  # Remove the oldest element

# # print("Predicted sales for the next 5 days:", predictions)

# %%
x_input=np.array(sales[-n_feature:])
temp=list(x_input)
temp
# Out:
# [187, 196, 210]
